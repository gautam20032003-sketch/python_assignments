# %% [markdown]
# <a href="https://colab.research.google.com/github/gautam20032003-sketch/python_assignments/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s={1,2,3,4,5}
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s={1,2,3,4}
s.add(5)
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s={1,2,3,4,5,6}
s.remove(6)
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s={1,2,3,4,5}
s.discard(6)
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s={4,5,6,7,8}
print(len(s))
# Out:
# 5

# %%
s={1,2,3,4,5,6}
for i in s:
  if i==7:
     print("exists")

# %%
s={1,2,3,4,5}
print(s.clear())
# Out:
# None

# %%
list=[1,2,2,3,4,5,5,6]
a=set(list)
print(a)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a=set()
print(type(a))

# %%
# Iterate through a set and print each element.
s={1,2,3,4,5}
for i in s:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
s1={1,2,3,4,5}
s2={4,5,6,7,8}
# s2.union(s1)
s2|s1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1={1,2,3,4,5}
s2={3,4,5,6,7,8}
s1&s2
# Out:
# {3, 4, 5}

# %%
s1={1,2,3,4}
s2={3,4,5,6}
s1-s2
# Out:
# {1, 2}

# %%
s1={1,2,3,4,5}
s2={3,4,5,6,7}
s1.symmetric_difference(s2)
# Out:
# {1, 2, 6, 7}

# %%
s={1,2}
s2={1,2,3,4}
s.issubset(s2)
# Out:
# True

# %%
s={1,2,3,4}
s2={1,2}
print(s.issuperset(s2))
# Out:
# True

# %%
s1 = {1, 2, 3}
s2 = {4, 5, 6}
print(s1.isdisjoint(s2))
# Out:
# True

# %%
s1={1,2,3}
s2={3,4,5}
s1.update(s2)
print(s1)
# Out:
# {1, 2, 3, 4, 5}

# %%
s={10,20,30,40}
s.pop()
print(s)
# Out:
# {10, 20, 30}

# %%
s1={1,2,3,4}
s2={3,4,5,6}
s3={4,5,6,3}
commom=s1&s2&s3
print(commom)
# Out:
# {3, 4}

# %%
s="this is python"
unique=set(s)
print(unique)

# %%
s="python is easy and python is powerful"
words=s.split()
unique_words=set(words)
print(len(unique_words))
# Out:
# 5

# %%
list1=[1,2,3,4]
list2=[3,4,5,6]
common=list(set(list1)&set(list2))
print(common)
# Out:
# [3, 4]

# %%
s1={1,2,3,4}
s2={3,4,5,6}
result=s1^s2
print(result)
# Out:
# {1, 2, 5, 6}

# %%
list=[1,2,3,2,4,5,1,7,8]
a=set()
duplicates=set()
for i in list:
  if i in a:
    duplicates.add(i)
  else:
    a.add(i)
print(duplicates)
# Out:
# {1, 2}

# %%
s1="silent"
s2="listen"
is_anagram=True
for i in s1:
  if i not in s2:
    is_anagram=False
if is_anagram:
  print("anagram")
else:
    print("not anagram")
# Out:
# anagram

# %%
s={1,2,3,4,5,6,7,8}
odd_nums={i for i in s if i%2!=0}
print(odd_nums)
# Out:
# {1, 3, 5, 7}

# %%
squares={i*i for i in range(1, 11)}
print(squares)

# %%
set={2,12,3,4,15,8,25}
new_set={i for i in set if i > 10 }
print(new_set)
